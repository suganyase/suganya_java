# %% [markdown]
# <a href="https://colab.research.google.com/github/suganyase/suganya_java/blob/main/Question14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import java.util.Calendar;
public class currentdate {
   public static void main(String[] args) { 
    Calendar c = Calendar.getInstance();
      System.out.println("Current Date :"); 
      System.out.format("%tB %te, %tY%n", c, c, c);
    
   }
}
# Out:
#   File "<ipython-input-1-a578bfb02f62>", line 3
#     Float f1 = 8.6f;
#                  ^
# SyntaxError: invalid decimal literal
