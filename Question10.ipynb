# %% [markdown]
# <a href="https://colab.research.google.com/github/suganyase/suganya_java/blob/main/Question10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
//A.java

public class A {  
  private void message(){System.out.println("Java Assignment"); }  
} 

//callingmethod.java

import java.lang.reflect.Method;  
public class callingmethod{  
public static void main(String[] args)throws Exception{  
  
    Class c = Class.forName("A");  
    Object o= c.newInstance();  
    Method m =c.getDeclaredMethod("message", null);  
    m.setAccessible(true);  
    m.invoke(o, null);  
}  
}
# Out:
#   File "<ipython-input-1-a578bfb02f62>", line 3
#     Float f1 = 8.6f;
#                  ^
# SyntaxError: invalid decimal literal
